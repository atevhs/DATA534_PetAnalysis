# %% [raw]
# import requests
# import pandas as pd
# import time
# dfs = []
# method = "get"
# my_token = "eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9..rKGDQdBuwslY_IiR7DQBp9aVmLWnubFYgv0ACyNLBPIb9JZE2LYzFguU9H6_Ig77zBxlCkwf69dduea6NLpwarKKbX73EUBWvrEt7RjzDWVtBIvxzyiGMRPeuaQTaG5FUcKxUKZAyM2EOjIoYRPeMQim_m3dxDnj6HUtrvAK4zQB43wE_zwhbDVqBLIY-v-kXj5-ShRDB9HxH01Wvhuy7l8BMXA37w61o6GyqsEqBOl3B0gqkkKugn9Q0YgBRXYFMmkMJNPvG0KrqSZYjsQUTXxBtV6RnraUvtRBjWPCoxBh5ksnEUrYJwhr63ZZqZOfY-jOD_FIKOVvAeRv08A8CA"
# head = {'Authorization': 'Bearer {}'.format(my_token)}
# url = "https://api.petfinder.com/v2/animals?type=dog&page=1"
# rsp = requests.request(method, url, headers= head)
# page = pd.DataFrame.from_dict((rsp.json()['pagination']))
# for i in range(1,600): #page['total_pages']['next']+1):
#     print(i)
#     url = "https://api.petfinder.com/v2/animals?type=dog&page=" + str(i)
#     rsp = requests.request(method, url, headers= head)
#     df = pd.DataFrame.from_dict((rsp.json()['animals']))
#     dfs.append(df)
#     time.sleep(1)
# print("finished!")
# combined2 = pd.concat(dfs)
# combined2
# combined2.to_csv("Dog Data all.csv")

# %%
combined2
# Out:
#           id organization_id  \
# 0   59725198           MN382
# 1   59725191           FL279
# 2   59725182          TX1003
# 3   59725183          TX1003
# 4   59725181          TX1003
# ..       ...             ...
# 15  59714577           WA636
# 16  59714572           WA552
# 17  59714566            CO91
# 18  59714563           NC863
# 19  59714562           CA474
#
#                                                   url type species  \
# 0   https://www.petfinder.com/dog/maskwa-cree-5972...  Dog     Dog
# 1   https://www.petfinder.com/dog/simba-59725191/f...  Dog     Dog
# 2   https://www.petfinder.com/dog/a378185-59725182...  Dog     Dog
# 3   https://www.petfinder.com/dog/a378112-59725183...  Dog     Dog
# 4   https://www.petfinder.com/dog/sara-59725181/tx...  Dog     Dog
# ..                                                ...  ...     ...
# 15  https://www.petfinder.com/dog/harvey-59714577/...  Dog     Dog
# ...
