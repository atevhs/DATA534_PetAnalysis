# %%
from location import *

# %%
from plot import *

# %%
from assoc_rules import *

# %%
get_shelter()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 get_shelter()
#
# File ~\2022MDS\Block 4\Data-534\Project\Group\DATA534_PetAnalysis\petanalysis\location.py:18, in get_shelter(postcode)
#      16 def get_shelter(postcode = None):
# ---> 18     us =  pd.read_csv("petanalysis/US_postcode.csv", dtype = str)
#      20     if postcode == None:
#      21         try:
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
assoc_rules()
# Out:
# C:\Users\sophiechen\anaconda3\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#                                            antecedents  \
# 140                                         (env_cats)
# 138                               (env_dogs, env_cats)
# 164                  (env_dogs, Mixed_breed, age_Baby)
# 20                                          (env_cats)
# 168                (env_dogs, shots_current, age_Baby)
# 33                                (env_dogs, age_Baby)
# 166                           (env_children, age_Baby)
# 170                           (env_children, age_Baby)
# 439       (env_children, spayed_neutered, Mixed_breed)
# 34                            (env_children, age_Baby)
# 165              (Mixed_breed, env_children, age_Baby)
# ...

# %%
visualize()
# Out:
# Select one of these menu options:
# 1    : Plot a histogram of male and female adoptable dogs in each age group.
# 2    : View a heat map of dog sizes in each age group.
# x    : Quit the session
# Enter your selection: 1
# C:\Users\sophiechen\anaconda3\lib\site-packages\seaborn\categorical.py:381: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(mpl.__version__) < "3.0":
# C:\Users\sophiechen\anaconda3\lib\site-packages\setuptools\_distutils\version.py:351: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# C:\Users\sophiechen\anaconda3\lib\site-packages\seaborn\axisgrid.py:130: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(mpl.__version__) < LooseVersion("3.0"):
# ...
